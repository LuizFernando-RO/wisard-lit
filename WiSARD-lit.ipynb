# %%
# -*- coding: utf-8 -*-

from bs4 import BeautifulSoup

f = open('pagina_research_gate.html')

source_code = f.read()

soup = BeautifulSoup(source_code, "lxml")

#reference = soup.findAll('a', {'class':'nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare'}, limit=None)

reference = soup.findAll(itemprop="mainEntityOfPage")

i = 0

for ref in reference:
    
    print(i, ref.text, ref['href'])
    i += 1
# Out:
# 0 Extracting fuzzy rules from "mental" images generated by a modified WISARD perceptron. https://www.researchgate.net/publication/221165962_Extracting_fuzzy_rules_from_mental_images_generated_by_a_modified_WISARD_perceptron?ev=project
# 1 Um sistema de viṣo artificial para o controle de persegui̤̣o de movimento por uma plataforma Steward https://www.researchgate.net/publication/236855663_Um_sistema_de_visao_artificial_para_o_controle_de_perseguicao_de_movimento_por_uma_plataforma_Steward?ev=project
# 2 Rock-paper-scissors WiSARD https://www.researchgate.net/publication/260422498_Rock-paper-scissors_WiSARD?ev=project
# 3 Credit analysis with a clustering RAM-based neural classifier https://www.researchgate.net/publication/265786702_Credit_analysis_with_a_clustering_RAM-based_neural_classifier?ev=project
# 4 Advances in Weightless Neural Systems https://www.researchgate.net/publication/265786785_Advances_in_Weightless_Neural_Systems?ev=project
# ...
